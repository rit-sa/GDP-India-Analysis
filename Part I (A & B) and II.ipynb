# %%
##PART I-A##

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Export the data in python 
gdp= pd.read_csv("D:\\upgrad\\ab40c054-5031-4376-b52e-9813e776f65e.csv")
gdp.head(3)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
#
#     Haryana      ...        Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 0  297539.0      ...         359433.0  19208.0       724049.0     115523.0
# 1  347032.0      ...         401493.0  21663.0       822903.0     131835.0
# 2  400662.0      ...         452186.0  25593.0       944146.0     149817.0
#
#    West Bengal1  Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  \
# ...

# %%
#Remving all '(% Growth over the previous year)' and 'GSDP - CURRENT PRICES (` in Crore)' for the year 2016-17.
ss1= gdp.iloc[7:10]
ss1.head()
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 7  (% Growth over previous year)  2013-14            12.85              16.38
# 8  (% Growth over previous year)  2014-15            13.40              14.79
# 9  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana      ...        \
# 7  13.31  12.30         16.44  -5.77    11.47    15.45      ...
# 8  11.45  17.92         13.69  13.12    10.82     9.18      ...
# 9  13.19  10.59         10.98  10.75    11.09    10.91      ...
#
#    Telangana  Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# 7      12.63    18.14          14.73        13.64           NaN
# 8      13.05    15.92          10.51         8.12           NaN
# 9      12.61      NaN          10.58        13.65           NaN
#
#    Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry  All_India GDP
# ...

# %%
#remove West bengal
aa= ss1.drop(columns=["West Bengal1"])
aa.head()
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 7  (% Growth over previous year)  2013-14            12.85              16.38
# 8  (% Growth over previous year)  2014-15            13.40              14.79
# 9  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana      ...        \
# 7  13.31  12.30         16.44  -5.77    11.47    15.45      ...
# 8  11.45  17.92         13.69  13.12    10.82     9.18      ...
# 9  13.19  10.59         10.98  10.75    11.09    10.91      ...
#
#    Tamil Nadu  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 7       13.51      12.63    18.14          14.73        13.64
# 8       12.51      13.05    15.92          10.51         8.12
# 9       10.99      12.61      NaN          10.58        13.65
#
#    Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry  All_India GDP
# ...

# %%
aa.set_index('Duration', inplace = True)
aa.head()
# Out:
#                      Items  Description  Andhra Pradesh   Arunachal Pradesh  \
# Duration
# 2013-14   (% Growth over previous year)            12.85              16.38
# 2014-15   (% Growth over previous year)            13.40              14.79
# 2015-16   (% Growth over previous year)            15.85              12.07
#
#           Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  \
# Duration
# 2013-14   13.31  12.30         16.44  -5.77    11.47    15.45
# 2014-15   11.45  17.92         13.69  13.12    10.82     9.18
# 2015-16   13.19  10.59         10.98  10.75    11.09    10.91
#
#           Himachal Pradesh      ...        Tamil Nadu  Telangana  Tripura  \
# Duration                        ...
# 2013-14              14.42      ...             13.51      12.63    18.14
# 2014-15              10.14      ...             12.51      13.05    15.92
# 2015-16                NaN      ...             10.99      12.61      NaN
#
# ...

# %%
# remove Item Description
bb= aa.drop(columns=["Items  Description"])
bb.head()
# Out:
#           Andhra Pradesh   Arunachal Pradesh  Assam  Bihar  Chhattisgarh  \
# Duration
# 2013-14             12.85              16.38  13.31  12.30         16.44
# 2014-15             13.40              14.79  11.45  17.92         13.69
# 2015-16             15.85              12.07  13.19  10.59         10.98
#
#             Goa  Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  \
# Duration
# 2013-14   -5.77    11.47    15.45             14.42            10.09
# 2014-15   13.12    10.82     9.18             10.14             4.70
# 2015-16   10.75    11.09    10.91               NaN            17.91
#
#               ...        Tamil Nadu  Telangana  Tripura  Uttar Pradesh  \
# Duration      ...
# 2013-14       ...             13.51      12.63    18.14          14.73
# 2014-15       ...             12.51      13.05    15.92          10.51
# 2015-16       ...             10.99      12.61      NaN          10.58
#
# ...

# %%
# NaN replace with Mean
bb.replace(np.NaN,bb.mean(),inplace=True)

bb.head()
# Out:
#           Andhra Pradesh   Arunachal Pradesh  Assam  Bihar  Chhattisgarh  \
# Duration
# 2013-14             12.85              16.38  13.31  12.30         16.44
# 2014-15             13.40              14.79  11.45  17.92         13.69
# 2015-16             15.85              12.07  13.19  10.59         10.98
#
#             Goa  Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  \
# Duration
# 2013-14   -5.77    11.47    15.45             14.42            10.09
# 2014-15   13.12    10.82     9.18             10.14             4.70
# 2015-16   10.75    11.09    10.91             12.28            17.91
#
#               ...        Tamil Nadu  Telangana  Tripura  Uttar Pradesh  \
# Duration      ...
# 2013-14       ...             13.51      12.63    18.14          14.73
# 2014-15       ...             12.51      13.05    15.92          10.51
# 2015-16       ...             10.99      12.61    17.03          10.58
#
# ...

# %%
# Year wise 
ss =bb.T
ss.head()
# Out:
# Duration           2013-14  2014-15  2015-16
# Andhra Pradesh       12.85    13.40    15.85
# Arunachal Pradesh    16.38    14.79    12.07
# Assam                13.31    11.45    13.19
# Bihar                12.30    17.92    10.59
# Chhattisgarh         16.44    13.69    10.98

# %%
ss["Average"]= ss.mean(axis=1)
ss.head(38)
# Out:
# Duration                   2013-14  2014-15  2015-16    Average
# Goa                          -5.77    13.12   10.750   6.033333
# Meghalaya                     4.87     6.41    9.580   6.953333
# Odisha                       12.95    10.37    6.190   9.836667
# Sikkim                       12.35     9.72    9.390  10.486667
# Jammu & Kashmir              10.09     4.70   17.910  10.900000
# Gujarat                      11.47    10.82   11.090  11.126667
# Punjab                       12.42     9.95   11.185  11.185000
# All_India GDP                12.97    10.65    9.990  11.203333
# Maharashtra                  13.74     8.78   11.260  11.260000
# Rajasthan                    11.27    11.37   11.320  11.320000
# Jharkhand                     7.92    15.14   11.440  11.500000
# Uttarakhand                  13.64     8.12   13.650  11.803333
# Haryana                      15.45     9.18   10.910  11.846667
# Uttar Pradesh                14.73    10.51   10.580  11.940000
# ...

# %%
ss= ss.sort_values(by='Average', ascending=1)
ss.head(1)
# Out:
# Duration  2013-14  2014-15  2015-16   Average
# Goa         -5.77    13.12    10.75  6.033333

# %%
plt.figure(figsize= (30,30))
sns.set_style("whitegrid")
sns.set(font_scale= 3)
sns.barplot(x=ss["Average"],y=ss.index, data=ss)
plt.xlabel("Average Result")
plt.title("Average growth")
plt.ylabel("State")
plt.show()

# %%
#plot the total GDP of 2015-16
tt1= gdp.iloc[4:5]
tt1.head()
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 4  485184.0      ...         575631.0      NaN      1153795.0     184091.0
#
#    West Bengal1  Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  \
# 4           NaN                        NaN     30304.0  551963.0     26533.0
#
#    All_India GDP
# 4     13675331.0
#
# [1 rows x 36 columns]

# %%
ss4 =tt1.replace(np.NaN,0)
ss4
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 4  485184.0      ...         575631.0      0.0      1153795.0     184091.0
#
#    West Bengal1  Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  \
# 4           0.0                        0.0     30304.0  551963.0     26533.0
#
#    All_India GDP
# 4     13675331.0
#
# [1 rows x 36 columns]

# %%
bb2= ss4.drop(columns=["All_India GDP"])
bb2.head()
# Out:
#                           Items  Description  Andhra Pradesh   \
# Duration
# 2015-16   GSDP - CURRENT PRICES (` in Crore)         609934.0
#
#           Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa  \
# Duration
# 2015-16             18784.0  224234.0  413503.0      260776.0  45002.0
#
#            Gujarat   Haryana  Himachal Pradesh     ...      Tamil Nadu  \
# Duration                                           ...
# 2015-16   994316.0  485184.0               0.0     ...       1212668.0
#
#           Telangana  Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# Duration
# 2015-16    575631.0      0.0      1153795.0     184091.0           0.0
#
#           Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry
# Duration
# 2015-16                         0.0     30304.0  551963.0     26533.0
#
# [1 rows x 34 columns]

# %%
bb3= bb2.drop(columns=["Items  Description"])
bb3.head()
# Out:
#           Andhra Pradesh   Arunachal Pradesh     Assam     Bihar  \
# Duration
# 2015-16          609934.0            18784.0  224234.0  413503.0
#
#           Chhattisgarh      Goa   Gujarat   Haryana  Himachal Pradesh  \
# Duration
# 2015-16       260776.0  45002.0  994316.0  485184.0               0.0
#
#           Jammu & Kashmir     ...      Tamil Nadu  Telangana  Tripura  \
# Duration                      ...
# 2015-16          118387.0     ...       1212668.0   575631.0      0.0
#
#           Uttar Pradesh  Uttarakhand  West Bengal1  Andaman & Nicobar Islands  \
# Duration
# 2015-16       1153795.0     184091.0           0.0                        0.0
#
#           Chandigarh     Delhi  Puducherry
# Duration
# 2015-16      30304.0  551963.0     26533.0
#
# [1 rows x 33 columns]

# %%
bb4 =bb3.T
bb4.tail(2)
# Out:
# Duration     2015-16
# Delhi       551963.0
# Puducherry   26533.0

# %%
bb5= bb4.sort_values("2015-16",ascending= False).head(5)
bb5.head()
# Out:
# Duration           2015-16
# Tamil Nadu       1212668.0
# Uttar Pradesh    1153795.0
# Karnataka        1027068.0
# Gujarat           994316.0
# Andhra Pradesh    609934.0

# %%
plt.figure(figsize= (10,10))
sns.set_style("whitegrid")
sns.barplot(y=bb5["2015-16"], x=bb5.index, data=bb5)
plt.ylabel("GSDP - CURRENT PRICES (` in Crore))")
plt.title("Top 5 States")
plt.xlabel("State")

plt.show()

# %%
#Here we are getting 0 value for a few states as those are NA in data sheet so drop out from the list 
bb7= bb4.drop(["Andaman & Nicobar Islands","West Bengal1","Tripura", "Rajasthan","Punjab", "Himachal Pradesh", "Nagaland", "Manipur","Maharashtra", "Mizoram" ])
bb7.head()
# Out:
# Duration            2015-16
# Andhra Pradesh     609934.0
# Arunachal Pradesh   18784.0
# Assam              224234.0
# Bihar              413503.0
# Chhattisgarh       260776.0

# %%
bb8= bb7.sort_values("2015-16",ascending= True).head(5)      
bb8.head()
# Out:
# Duration           2015-16
# Sikkim             16637.0
# Arunachal Pradesh  18784.0
# Puducherry         26533.0
# Meghalaya          26745.0
# Chandigarh         30304.0

# %%
plt.figure(figsize= (10,10))
sns.set_style("whitegrid")
sns.barplot(y=bb8["2015-16"], x=bb8.index, data=bb8)
plt.ylabel("GSDP - CURRENT PRICES (` in Crore))")
plt.title("Bottom 5 States")
plt.xlabel("State")
plt.show()

# %%
## PART I-B ##

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import glob

# %%
all_files = glob.glob("D:\\upgrad\\sgdp\\*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename,encoding = "ISO-8859-1")
    df = df.loc[::,['Item','2014-15']]
    df.columns = df.columns.str.replace('*','').str.replace('*','')
    df = df.set_index(['Item']).T
    df['State'] = filename.split('-')[1]
    df= df.set_index('State')
    li.append(df)
pp = pd.concat(li, axis=0)
pp.head()
# Out:
# D:\Program Files (x86)\Anaaaaa\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()
#                    Agriculture, forestry and fishing  Air transport  \
# State
# Andhra_Pradesh                            14819416.0        14900.0
# Arunachal_Pradesh                           686117.0            0.0
# Assam                                      3855548.0        26223.0
# Bihar                                      7951890.0        13599.0
# Chandigarh                                   16233.0        12391.0
#
#                    Communication & services related to broadcasting  \
# State
# Andhra_Pradesh                                             928756.0
# ...

# %%
ssk =pp.T
ssk.head(48)
# Out:
# State                                               Andhra_Pradesh  \
# Agriculture, forestry and fishing                       14819416.0
# Air transport                                              14900.0
# Communication & services related to broadcasting          928756.0
# Construction                                             4664889.0
# Crops                                                    7893514.0
# Electricity, gas, water supply & other utility ...       1151729.0
# Financial services                                       1900863.0
# Fishing and aquaculture                                  2270664.0
# Forestry and logging                                      346160.0
# Gross State Domestic Product                            52646842.0
# Hotels & restaurants                                      517400.0
# Livestock                                                4309078.0
# Manufacturing                                            4672266.0
# ...

# %%
rd = ssk.iloc[[9,15,17,24,31], :]
rd.head()
# Out:
# State                         Andhra_Pradesh  Arunachal_Pradesh       Assam  \
# Gross State Domestic Product      52646842.0          1676119.0  19809800.0
# Per Capita GSDP (Rs.)               104977.0           112718.0     60621.0
# Primary                           16303716.0           716959.0   5326697.0
# Secondary                         10488884.0           287489.0   4033091.0
# Tertiary                          22032942.0           631844.0   9307109.0
#
# State                              Bihar  Chandigarh  Chhattisgarh        Goa  \
# Gross State Domestic Product  37391988.0   2784426.0    23498180.0  4063307.0
# Per Capita GSDP (Rs.)            33954.0    250398.0       86860.0   271793.0
# Primary                        8019997.0     16412.0     6400817.0   312129.0
# Secondary                      5984896.0    312693.0     8238886.0  1547536.0
# Tertiary                      22179969.0   2426008.0     7588778.0  1738217.0
#
# ...

# %%
#Gross State Domestic Product for 2014-15 
# Per Capita GSDP Rs. for 2014-15
oo =rd.T
oo.head(2)
# Out:
#                    Gross State Domestic Product  Per Capita GSDP (Rs.)  \
# State
# Andhra_Pradesh                       52646842.0               104977.0
# Arunachal_Pradesh                     1676119.0               112718.0
#
#                       Primary   Secondary    Tertiary
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0
# Arunachal_Pradesh    716959.0    287489.0    631844.0

# %%
#Top 5 state as per Per Capita GSDP (Rs.)
vb= oo.sort_values("Per Capita GSDP (Rs.)",ascending= False).head(5)
vb.head()
# Out:
#             Gross State Domestic Product  Per Capita GSDP (Rs.)    Primary  \
# State
# Goa                            4063307.0               271793.0   312129.0
# Chandigarh                     2784426.0               250398.0    16412.0
# Sikkim                         1520933.0               240274.0   138776.0
# Haryana                       43746207.0               164077.0  8040424.0
# Kerala                        52600230.0               154778.0  6489442.0
#
#              Secondary    Tertiary
# State
# Goa          1547536.0   1738217.0
# Chandigarh    312693.0   2426008.0
# Sikkim        845253.0    483103.0
# Haryana     12561411.0  19226568.0
# Kerala      12070040.0  29673778.0

# %%
plt.figure(figsize= (10,10))
sns.set_style("whitegrid")
sns.barplot(y=vb["Per Capita GSDP (Rs.)"], x=vb.index, data=vb)
plt.ylabel("Per Capita GSDP (Rs.)")
plt.title("Top 5 States as GDP per capita")
plt.xlabel("State")
plt.show()

# %%
#Bottom 5 state as per Per Capita GSDP (Rs.)
vv= oo.sort_values("Per Capita GSDP (Rs.)",ascending= True).head(5)
vv.head(38)
# Out:
#                Gross State Domestic Product  Per Capita GSDP (Rs.)  \
# State
# Bihar                            37391988.0                33954.0
# Uttar_Pradesh                   104337115.0                49450.0
# Manipur                           1804276.0                58442.0
# Assam                            19809800.0                60621.0
# Jharkhand                        21710718.0                62091.0
#
#                   Primary   Secondary    Tertiary
# State
# Bihar           8019997.0   5984896.0  22179969.0
# Uttar_Pradesh  25999255.0  25548724.0  45968959.0
# Manipur          383140.0    220173.0   1177334.0
# Assam           5326697.0   4033091.0   9307109.0
# Jharkhand       5248354.0   6241471.0   8133341.0

# %%
plt.figure(figsize= (10,10))
sns.set_style("whitegrid")
sns.barplot(y=vv["Per Capita GSDP (Rs.)"], x=vv.index, data=vv)
plt.ylabel("Per Capita GSDP (Rs.)")
plt.title("Bottom 5 States as GDP per capita")
plt.xlabel("State")
plt.show()

# %%
# Ratio of highest per capita GDP to the lowest per capita GDP.
aa = max(oo["Per Capita GSDP (Rs.)"])/min(oo["Per Capita GSDP (Rs.)"])
print(aa)
# Out:
# 8.004741709371503

# %%
# Create a new variable
pf =rd.T
pf.head(2)
# Out:
#                    Gross State Domestic Product  Per Capita GSDP (Rs.)  \
# State
# Andhra_Pradesh                       52646842.0               104977.0
# Arunachal_Pradesh                     1676119.0               112718.0
#
#                       Primary   Secondary    Tertiary
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0
# Arunachal_Pradesh    716959.0    287489.0    631844.0

# %%
# Create Primary percentage

pf["Primary %"] = pf['Primary']/pf['Gross State Domestic Product']*100
pf.head(2)
# Out:
#                    Gross State Domestic Product  Per Capita GSDP (Rs.)  \
# State
# Andhra_Pradesh                       52646842.0               104977.0
# Arunachal_Pradesh                     1676119.0               112718.0
#
#                       Primary   Secondary    Tertiary  Primary %
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0  30.968080
# Arunachal_Pradesh    716959.0    287489.0    631844.0  42.774946

# %%
# Create Secondary percentage

pf["Secondary %"] = pf['Secondary']/pf['Gross State Domestic Product']*100
pf.head(2)
# Out:
#                    Gross State Domestic Product  Per Capita GSDP (Rs.)  \
# State
# Andhra_Pradesh                       52646842.0               104977.0
# Arunachal_Pradesh                     1676119.0               112718.0
#
#                       Primary   Secondary    Tertiary  Primary %  Secondary %
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0  30.968080    19.923102
# Arunachal_Pradesh    716959.0    287489.0    631844.0  42.774946    17.152064

# %%
# Create Tertiary percentage
pf["Tertiary %"] = pf['Tertiary']/pf['Gross State Domestic Product']*100
pf.head()
# Out:
#                    Gross State Domestic Product  Per Capita GSDP (Rs.)  \
# State
# Andhra_Pradesh                       52646842.0               104977.0
# Arunachal_Pradesh                     1676119.0               112718.0
# Assam                                19809800.0                60621.0
# Bihar                                37391988.0                33954.0
# Chandigarh                            2784426.0               250398.0
#
#                       Primary   Secondary    Tertiary  Primary %  Secondary %  \
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0  30.968080    19.923102
# Arunachal_Pradesh    716959.0    287489.0    631844.0  42.774946    17.152064
# Assam               5326697.0   4033091.0   9307109.0  26.889201    20.359070
# Bihar               8019997.0   5984896.0  22179969.0  21.448437    16.005825
# Chandigarh            16412.0    312693.0   2426008.0   0.589421    11.230070
#
#                    Tertiary %
# State
# ...

# %%
pf1= pf.drop(columns=["Gross State Domestic Product", "Per Capita GSDP (Rs.)","Primary", "Secondary", "Tertiary"])
pf1.head()
# Out:
#                    Primary %  Secondary %  Tertiary %
# State
# Andhra_Pradesh     30.968080    19.923102   41.850453
# Arunachal_Pradesh  42.774946    17.152064   37.696846
# Assam              26.889201    20.359070   46.982347
# Bihar              21.448437    16.005825   59.317437
# Chandigarh          0.589421    11.230070   87.127760

# %%
# Plotting the percentage contribution of primary, secondary and tertiary sectors as a percentage of total GDP for all the states.
plt.figure(figsize=(11,11))
plt.title("Percentage Contribution of Primary, Secondary and Tertiary", size = 19)
pf2 = sns.heatmap(pf1, annot = True)

# %%
cc =rd.T
cc.head(2)
# Out:
#                    Gross State Domestic Product  Per Capita GSDP (Rs.)  \
# State
# Andhra_Pradesh                       52646842.0               104977.0
# Arunachal_Pradesh                     1676119.0               112718.0
#
#                       Primary   Secondary    Tertiary
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0
# Arunachal_Pradesh    716959.0    287489.0    631844.0

# %%
# GDP per capita (C1, C2, C3, C4)
cc["Percentile"] = cc["Per Capita GSDP (Rs.)"].rank(pct = True)
cc.head()
# Out:
#                    Gross State Domestic Product  Per Capita GSDP (Rs.)  \
# State
# Andhra_Pradesh                       52646842.0               104977.0
# Arunachal_Pradesh                     1676119.0               112718.0
# Assam                                19809800.0                60621.0
# Bihar                                37391988.0                33954.0
# Chandigarh                            2784426.0               250398.0
#
#                       Primary   Secondary    Tertiary  Percentile
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0    0.500000
# Arunachal_Pradesh    716959.0    287489.0    631844.0    0.535714
# Assam               5326697.0   4033091.0   9307109.0    0.142857
# Bihar               8019997.0   5984896.0  22179969.0    0.035714
# Chandigarh            16412.0    312693.0   2426008.0    0.964286

# %%
#It has help to create state wise catgory
cc["Category"] = pd.qcut(cc["Per Capita GSDP (Rs.)"],[0,0.20,0.50,0.85,1], labels= ["C4","C3","C2","C1"])
cc.head()
# Out:
#                    Gross State Domestic Product  Per Capita GSDP (Rs.)  \
# State
# Andhra_Pradesh                       52646842.0               104977.0
# Arunachal_Pradesh                     1676119.0               112718.0
# Assam                                19809800.0                60621.0
# Bihar                                37391988.0                33954.0
# Chandigarh                            2784426.0               250398.0
#
#                       Primary   Secondary    Tertiary  Percentile Category
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0    0.500000       C3
# Arunachal_Pradesh    716959.0    287489.0    631844.0    0.535714       C2
# Assam               5326697.0   4033091.0   9307109.0    0.142857       C4
# Bihar               8019997.0   5984896.0  22179969.0    0.035714       C4
# Chandigarh            16412.0    312693.0   2426008.0    0.964286       C1

# %%
df3 = pd.merge(pp,cc, on = "State")
df3.head(3)
# Out:
#                    Agriculture, forestry and fishing  Air transport  \
# State
# Andhra_Pradesh                            14819416.0        14900.0
# Arunachal_Pradesh                           686117.0            0.0
# Assam                                      3855548.0        26223.0
#
#                    Communication & services related to broadcasting  \
# State
# Andhra_Pradesh                                             928756.0
# Arunachal_Pradesh                                           19568.0
# Assam                                                      357619.0
#
#                    Construction      Crops  \
# State
# Andhra_Pradesh        4664889.0  7893514.0
# Arunachal_Pradesh      147842.0   415520.0
# Assam                 1733568.0  2890544.0
#
#                    Electricity, gas, water supply & other utility services  \
# State
# Andhra_Pradesh                                             1151729.0
# ...

# %%
df3.sort_values(by="Category",ascending = False).head()
# Out:
#             Agriculture, forestry and fishing  Air transport  \
# State
# Chandigarh                            16233.0        12391.0
# Goa                                  308507.0        46359.0
# Haryana                             8015238.0            NaN
# Sikkim                               137447.0            0.0
# Kerala                              5930617.0       125029.0
#
#             Communication & services related to broadcasting  Construction  \
# State
# Chandigarh                                           46399.0      133321.0
# Goa                                                  44028.0      165819.0
# Haryana                                             479658.0     3702571.0
# Sikkim                                               12064.0       82058.0
# Kerala                                              884767.0     7314003.0
#
#                 Crops  \
# State
# Chandigarh     1659.0
# Goa          140421.0
# Haryana     4636731.0
# Sikkim       114976.0
# ...

# %%
df4 = df3[["Category", "Agriculture, forestry and fishing", "Mining and quarrying","Manufacturing","Electricity, gas, water supply & other utility services", "Construction", "Trade, repair, hotels and restaurants", "Transport, storage, communication & services related to broadcasting", "Financial services", "Real estate, ownership of dwelling & professional services", "Public administration", "Other services","Gross State Domestic Product_x"]]
df4
# Out:
#                   Category  Agriculture, forestry and fishing  \
# State
# Andhra_Pradesh          C3                         14819416.0
# Arunachal_Pradesh       C2                           686117.0
# Assam                   C4                          3855548.0
# Bihar                   C4                          7951890.0
# Chandigarh              C1                            16233.0
# Chhattisgarh            C3                          3948847.0
# Goa                     C1                           308507.0
# Gujarat                 C2                         13769969.0
# Haryana                 C1                          8015238.0
# Himachal_Pradesh        C2                          1514981.0
# Jharkhand               C4                          3211065.0
# Karnataka               C2                         11219422.0
# Kerala                  C1                          5930617.0
# Madhya_Pradesh          C4                         16235647.0
# ...

# %%
# Shorting by Category and Gross State Domestic Product
ty = df4.sort_values(by = ["Category","Gross State Domestic Product_x"], ascending = False)
ty.head()
# Out:
#            Category  Agriculture, forestry and fishing  Mining and quarrying  \
# State
# Kerala           C1                          5930617.0              558824.0
# Haryana          C1                          8015238.0               25186.0
# Goa              C1                           308507.0                3622.0
# Chandigarh       C1                            16233.0                 179.0
# Sikkim           C1                           137447.0                1329.0
#
#             Manufacturing  \
# State
# Kerala          4273567.0
# Haryana         7756921.0
# Goa             1177608.0
# Chandigarh       149631.0
# Sikkim           550697.0
#
#             Electricity, gas, water supply & other utility services  \
# State
# Kerala                                               482470.0
# Haryana                                             1101919.0
# Goa                                                  204110.0
# ...

# %%
df5 = df4.groupby("Category").sum()
df5.head()
# Out:
#           Agriculture, forestry and fishing  Mining and quarrying  \
# Category
# C4                               56735044.0             6096419.0
# C3                               42226888.0            10835771.0
# C2                               75209022.0            10373346.0
# C1                               14408042.0              589140.0
#
#           Manufacturing  \
# Category
# C4           24987032.0
# C3           22038331.0
# C2          109196530.0
# C1           13908424.0
#
#           Electricity, gas, water supply & other utility services  \
# Category
# C4                                                4310264.0
# C3                                                4604774.0
# C2                                               13823378.0
# C1                                                2030739.0
#
#           Construction  Trade, repair, hotels and restaurants  \
# Category
# C4          22775948.0                             27484595.0
# ...

# %%
#df5 = df4.set_index("Category")
#df5.head(70)

df6 =df5.T
df6.head(14)
# Out:
# Category                                                     C4           C3  \
# Agriculture, forestry and fishing                    56735044.0   42226888.0
# Mining and quarrying                                  6096419.0   10835771.0
# Manufacturing                                        24987032.0   22038331.0
# Electricity, gas, water supply & other utility ...    4310264.0    4604774.0
# Construction                                         22775948.0   15707921.0
# Trade, repair, hotels and restaurants                27484595.0   17245309.0
# Transport, storage, communication & services re...   16191800.0   12231484.0
# Financial services                                    7684498.0    5766226.0
# Real estate, ownership of dwelling & profession...   24177534.0   16224118.0
# Public administration                                13486630.0    7927173.0
# Other services                                       15859015.0   12815417.0
# ...

# %%
#  The sub-sectors contribution as a percentage of the GSDP of each category.

plt.figure(figsize=(13,12), dpi =90)
plt.title("The sub-sectors contribution as a percentage of the GSDP.", size = 17)
df7 = sns.heatmap(df6, annot = True, fmt=".1f", linewidths= 1, square = True, cmap="Blues_r")

# %%
##PART II##

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Export the data in python
do = pd.read_csv("D:\\upgrad\\Datapart2\\rs_session243_au570_1.1.csv")
do.head()
# Out:
#   Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0       1              A & N Islands                 0.68
# 1       2             Andhra Pradesh                 3.18
# 2       3          Arunachal Pradesh                15.16
# 3       4                      Assam                 6.24
# 4       5                      Bihar                  NaN
#
#    Primary - 2014-2015  Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# 0                 1.21                   0.51                       1.23
# 1                 4.35                   6.72                       3.36
# 2                10.89                  10.82                       7.47
# 3                 7.44                  15.36                       7.20
# 4                 2.09                    NaN                        NaN
#
#    Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# 0                       0.51                       1.69
# 1                       3.78                       5.20
# ...

# %%
new_s= do.rename(columns={"Level of Education - State" : "State"})
new_s.head()
# Out:
#   Sl. No.              State  Primary - 2012-2013  Primary - 2014-2015  \
# 0       1      A & N Islands                 0.68                 1.21
# 1       2     Andhra Pradesh                 3.18                 4.35
# 2       3  Arunachal Pradesh                15.16                10.89
# 3       4              Assam                 6.24                 7.44
# 4       5              Bihar                  NaN                 2.09
#
#    Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# 0                   0.51                       1.23
# 1                   6.72                       3.36
# 2                  10.82                       7.47
# 3                  15.36                       7.20
# 4                    NaN                        NaN
#
#    Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# 0                       0.51                       1.69
# 1                       3.78                       5.20
# ...

# %%
new_s.set_index('State', inplace = True)
new_s.head()
# Out:
#                   Sl. No.  Primary - 2012-2013  Primary - 2014-2015  \
# State
# A & N Islands           1                 0.68                 1.21
# Andhra Pradesh          2                 3.18                 4.35
# Arunachal Pradesh       3                15.16                10.89
# Assam                   4                 6.24                 7.44
# Bihar                   5                  NaN                 2.09
#
#                    Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# State
# A & N Islands                       0.51                       1.23
# Andhra Pradesh                      6.72                       3.36
# Arunachal Pradesh                  10.82                       7.47
# Assam                              15.36                       7.20
# Bihar                                NaN                        NaN
#
#                    Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# State
# ...

# %%
new = pd.merge(new_s,cc, on = "State")
new.head()
# Out:
#            Sl. No.  Primary - 2012-2013  Primary - 2014-2015  \
# State
# Assam            4                 6.24                 7.44
# Bihar            5                  NaN                 2.09
# Chandigarh       6                  NaN                  NaN
# Goa             11                  NaN                 0.20
# Gujarat         12                 0.74                 0.76
#
#             Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# State
# Assam                       15.36                        7.2
# Bihar                         NaN                        NaN
# Chandigarh                    NaN                        0.1
# Goa                          0.73                        NaN
# Gujarat                      0.89                        5.2
#
#             Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# State
# Assam                            7.05                      10.51
# Bihar                            2.98                       4.08
# ...

# %%
#combine all against state
new_a = new[["Per Capita GSDP (Rs.)","Primary - 2014-2015", "Upper Primary - 2014-2015", "Secondary - 2014-2015"]]
new_a.head()
# Out:
#             Per Capita GSDP (Rs.)  Primary - 2014-2015  \
# State
# Assam                     60621.0                 7.44
# Bihar                     33954.0                 2.09
# Chandigarh               250398.0                  NaN
# Goa                      271793.0                 0.20
# Gujarat                  141263.0                 0.76
#
#             Upper Primary - 2014-2015  Secondary - 2014-2015
# State
# Assam                           10.51                  27.06
# Bihar                            4.08                  25.90
# Chandigarh                       0.44                    NaN
# Goa                              0.07                  11.15
# Gujarat                          6.41                  25.04

# %%
new_b = new[["Primary - 2014-2015", "Upper Primary - 2014-2015", "Secondary - 2014-2015"]]
new_b.head()
# Out:
#             Primary - 2014-2015  Upper Primary - 2014-2015  \
# State
# Assam                      7.44                      10.51
# Bihar                      2.09                       4.08
# Chandigarh                  NaN                       0.44
# Goa                        0.20                       0.07
# Gujarat                    0.76                       6.41
#
#             Secondary - 2014-2015
# State
# Assam                       27.06
# Bihar                       25.90
# Chandigarh                    NaN
# Goa                         11.15
# Gujarat                     25.04

# %%
# Dropout as per Satat in diferent Level
plt.figure(figsize=(8,8))
plt.title("Dropout as per State in diferent Level", size = 17)
new_all = sns.heatmap(new_b, annot = True)

# %%
#orelation GDP per Capita vs Primary level Dropout for 2014-15
sns.jointplot("Per Capita GSDP (Rs.)", "Primary - 2014-2015", new_a, kind= 'reg')
plt.show()

# %%
#Corelation GDP per Capita vs Upper Primary level Dropout for 2014-15
sns.jointplot("Per Capita GSDP (Rs.)", "Upper Primary - 2014-2015", new_a, kind= 'reg')

plt.show()

# %%
#Corelation GDP per Capita vs Secondary level Dropout for 2014-15
sns.jointplot("Per Capita GSDP (Rs.)", "Secondary - 2014-2015", new_a, kind= 'reg')
plt.show()
